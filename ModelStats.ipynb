# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import load_model
import pickle

# %%
history = np.load("naive_model_train_history.pickle",allow_pickle=True)

model = load_model("naive_model.h5")
model.summary()

#PLOTS
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.title("Naive CNN Scene Classification Network Loss")
plt.legend()
plt.show()

plt.clf()   # clear figure

plt.plot(history['accuracy'], label='Training acc')
plt.plot(history['val_accuracy'], label='Validation acc')
plt.title("Naive CNN Scene Classification Accuracy")
plt.legend()
plt.show()

print("Validation Accuracy: " + str(max(history['val_accuracy'])))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 98, 98, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16928)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1083456
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# ...

# %%
history = np.load("tuned_model_train_history.npy", allow_pickle=True).item()

model = load_model("tuned_model.keras")
model.summary()

#PLOTS
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.title("Tuned CNN Scene Classification Network Loss")
plt.legend()
plt.show()

plt.clf()   # clear figure

plt.plot(history['accuracy'], label='Training acc')
plt.plot(history['val_accuracy'], label='Validation acc')
plt.title("Tuned CNN Scene Classification Accuracy")
plt.legend()
plt.show()

print("Validation Accuracy: " + str(max(history['val_accuracy'])))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 98, 98, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          9248
# ...

# %%
history = np.load("tuned_model_overfit_train_history.npy", allow_pickle=True).item()

model = load_model("tuned_model_overfit.keras")
model.summary()

#PLOTS
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.title("Overfitting Scene Classification Network Loss")
plt.legend()
plt.show()

plt.clf()   # clear figure

plt.plot(history['accuracy'], label='Training acc')
plt.plot(history['val_accuracy'], label='Validation acc')
plt.title("Overfitting Scene Classification Accuracy")
plt.legend()
plt.show()

print("Validation Accuracy: " + str(max(history['val_accuracy'])))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 98, 98, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          9248
# ...

# %%
history = np.load("regularized_train_history.npy", allow_pickle=True).item()

model = load_model("regularized_model.keras")
model.summary()

#PLOTS
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.title("Regularized/Dropout Scene Classification Network Loss")
plt.legend()
plt.show()

plt.clf()   # clear figure

plt.plot(history['accuracy'], label='Training acc')
plt.plot(history['val_accuracy'], label='Validation acc')
plt.title("Regularized/Dropout Scene Classification Accuracy")
plt.legend()
plt.show()

print("Validation Accuracy: " + str(max(history['val_accuracy'])))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 98, 98, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          9248
# ...
